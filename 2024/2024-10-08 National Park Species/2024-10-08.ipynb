# %% [raw]
# ---
# title: "National Park Species"
# author: Austin Mangelson
# date: 'Oct 14, 2024'
# format:
#   html:
#     code-fold: true
# execute:
#   enabled: true
#   warning: false
# ---

# %% [markdown]
# ## Import Data

# %% [markdown]
# Data from [https://github.com/rfordatascience/tidytuesday/blob/master/data/2024/2024-10-08/readme.md](https://github.com/rfordatascience/tidytuesday/blob/master/data/2024/2024-10-08/readme.md)

# %%
#load libraries
import polars as pl
from lets_plot import *
LetsPlot.setup_html()

#load in data 
url = "https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2024/2024-10-08/most_visited_nps_species_data.csv"
species_data = pl.read_csv(url)
species_data = species_data.with_columns(
    pl.col("ParkName").str.replace(" National Park$", "", literal=False).alias("ParkName")
)
species_data
# Out:
#             <div id="cMHHKy"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.4.1/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("cMHHKy").appendChild(div);
#                     };
#                     var e = document.getElementById("cMHHKy");
#                     e.appendChild(script);
#                 })()
#             </script>
# shape: (61_119, 28)
# ┌──────────┬──────────┬─────────────┬─────────────┬───┬─────────────┬────────────┬───────┬─────────┐
# │ ParkCode ┆ ParkName ┆ CategoryNam ┆ Order       ┆ … ┆ StateStatus ┆ OzoneSensi ┆ GRank ┆ SRank   │
# │ ---      ┆ ---      ┆ e           ┆ ---         ┆   ┆ ---         ┆ tiveStatus ┆ ---   ┆ ---     │
# │ str      ┆ str      ┆ ---         ┆ str         ┆   ┆ str         ┆ ---        ┆ str   ┆ str     │
# │          ┆          ┆ str         ┆             ┆   ┆             ┆ str        ┆       ┆         │
# ╞══════════╪══════════╪═════════════╪═════════════╪═══╪═════════════╪════════════╪═══════╪═════════╡
# │ ACAD     ┆ Acadia   ┆ Mammal      ┆ Artiodactyl ┆ … ┆ NA          ┆ NA         ┆ G5    ┆ ME: S5  │
# │          ┆          ┆             ┆ a           ┆   ┆             ┆            ┆       ┆         │
# │ ACAD     ┆ Acadia   ┆ Mammal      ┆ Artiodactyl ┆ … ┆ NA          ┆ NA         ┆ G5    ┆ ME: S5  │
# │          ┆          ┆             ┆ a           ┆   ┆             ┆            ┆       ┆         │
# │ ACAD     ┆ Acadia   ┆ Mammal      ┆ Carnivora   ┆ … ┆ NA          ┆ NA         ┆ G5    ┆ ME: S5  │
# │ ACAD     ┆ Acadia   ┆ Mammal      ┆ Carnivora   ┆ … ┆ NA          ┆ NA         ┆ G5    ┆ ME: SH  │
# │ ACAD     ┆ Acadia   ┆ Mammal      ┆ Carnivora   ┆ … ┆ NA          ┆ NA         ┆ G5    ┆ ME: S5  │
# │ …        ┆ …        ┆ …           ┆ …           ┆ … ┆ …           ┆ …          ┆ …     ┆ …       │
# │ ZION     ┆ Zion     ┆ Vascular    ┆ Solanales   ┆ … ┆ NA          ┆ NA         ┆ G5    ┆ UT: SNR │
# │          ┆          ┆ Plant       ┆             ┆   ┆             ┆            ┆       ┆         │
# │ ZION     ┆ Zion     ┆ Vascular    ┆ Vitales     ┆ … ┆ NA          ┆ NA         ┆ G4G5  ┆ UT: S1  │
# │          ┆          ┆ Plant       ┆             ┆   ┆             ┆            ┆       ┆         │
# │ ZION     ┆ Zion     ┆ Vascular    ┆ Vitales     ┆ … ┆ NA          ┆ NA         ┆ G4    ┆ UT: SNA │
# │          ┆          ┆ Plant       ┆             ┆   ┆             ┆            ┆       ┆         │
# │ ZION     ┆ Zion     ┆ Vascular    ┆ Zygophyllal ┆ … ┆ NA          ┆ NA         ┆ G5    ┆ UT: SNR │
# │          ┆          ┆ Plant       ┆ es          ┆   ┆             ┆            ┆       ┆         │
# │ ZION     ┆ Zion     ┆ Vascular    ┆ Zygophyllal ┆ … ┆ NA          ┆ NA         ┆ GNR   ┆ UT: SNA │
# │          ┆          ┆ Plant       ┆ es          ┆   ┆             ┆            ┆       ┆         │
# └──────────┴──────────┴─────────────┴─────────────┴───┴─────────────┴────────────┴───────┴─────────┘

# %% [markdown]
# ## Species Diversity by Park

# %%
species_per_park = species_data.select(["ParkName", "SciName"]).unique().group_by("ParkName").count().rename({"count":"number_of_species"}).sort("number_of_species", descending = True).head(10)
species_per_park

(
    ggplot(species_per_park, aes(x = "number_of_species", y = as_discrete("ParkName", order_by = "number_of_species", order=1))) + 
    geom_bar(stat = "identity") +
    labs(
        title = "Species Diversity by US National Park \n",
        x = "Number of Species",
        y = "Park Name"
    ) + 
    theme_minimal()
)
# Out:
# C:\Users\austi\AppData\Local\Temp\ipykernel_7324\3272089793.py:1: DeprecationWarning:
#
# `GroupBy.count` is deprecated. It has been renamed to `len`.
#    <div id="lP437W"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "ParkName":["Great Smoky Mountains","Yellowstone","Rocky Mountain","Grand Canyon","Glacier","Indiana Dunes","Joshua Tree","Grand Teton","Yosemite","Hot Springs"],
# "number_of_species":[28655.0,4175.0,3201.0,2707.0,2559.0,2483.0,2316.0,2245.0,2086.0,1972.0]
# },
# "mapping":{
# "x":"number_of_species",
# "y":"ParkName"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"ParkName"
# },{
# "type":"int",
# "column":"number_of_species"
# }],
# "mapping_annotations":[{
# "parameters":{
# "label":"ParkName",
# "order_by":"number_of_species",
# "order":1.0
# },
# "aes":"y",
# "annotation":"as_discrete"
# }]
# },
# "ggtitle":{
# "text":"Species Diversity by US National Park \n"
# },
# "guides":{
# "x":{
# "title":"Number of Species"
# },
# "y":{
# "title":"Park Name"
# }
# },
# "theme":{
# "name":"minimal"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "orientation":"y",
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("lP437W");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# Why is Great Smoky Mountains National Park so biodiverse?
#
# *"Great Smoky Mountains National Park is known to be the most biologically diverse in the entire National Park system. This biodiversity is in part a result of its past as a refuge for animals and plants migrating south away from glaciers. It can also be attributed to its mild, rainy climate. Scientists have identified 19,000 different species of plants and animals in the park and think that as many as 100,000 other species may have yet to be identified."*
#  -- [USGS](https://www.usgs.gov/geology-and-ecology-of-national-parks/ecology-great-smoky-mountains-national-park-0#:~:text=Great%20Smoky%20Mountains%20National%20Park%20is%20known%20to%20be%20the,to%20its%20mild%2C%20rainy%20climate.)

# %%
# grsm_taxonomy = (
# species_data
# .filter(pl.col("ParkCode") == "GRSM")
# .unique()
# .with_columns(
#     pl.col("SciName")
#     .str.split_exact(" ", 1)
#     .struct.rename_fields(["Genus", "Species"])
#     .alias("fields")
# ).unnest("fields")
# .select(["Order", "Family", "Genus"])
# .with_columns(pl.col("Species").str.to_titlecase())
# )
# grsm_taxonomy

# grsm_taxonomy.group_by("Genus").count().sort("count", descending = True)

# import plotly.express as px

# grsm_taxonomy_df = grsm_taxonomy_breakdown.to_pandas()

# grsm_taxonomy_df["Species"] = grsm_taxonomy_df["Species"].fillna("Unknown")

# fig = px.sunburst(
#    grsm_taxonomy_df,
#    path = ["Order", "Family", "Genus", "Species"],
#    values=None,
#    title = "Sunburst Chart of GRSM National Park"
# )

# fig.show()

# %% [markdown]
# ## National Parks Ranked by Biodiversity

# %%
import polars as pl

animals = (
    species_data
    .filter(
        pl.col("CategoryName").is_in(["Insect", "Spider/Scorpion", "Bird", "Other Non-vertebrates",
                                      "Mammal", "Fish", "Slug/Snail", "Reptile",
                                      "Crab/Lobster/Shrimp", "Amphibian"])
    )
    .with_columns(
        pl.when(pl.col("CategoryName") == "Slug/Snail").then(pl.lit("Invertebrate"))
        .when(pl.col("CategoryName") == "Other Non-vertebrates").then(pl.lit("Invertebrate"))
        .when(pl.col("CategoryName") == "Insect").then(pl.lit("Invertebrate"))
        .when(pl.col("CategoryName") == "Spider/Scorpion").then(pl.lit("Invertebrate"))
        .when(pl.col("CategoryName") == "Crab/Lobster/Shrimp").then(pl.lit("Invertebrate"))
        .otherwise(pl.col("CategoryName"))
        .alias("Category")
    )
    .group_by(["ParkName", "Category"])
    .count()
    .sort("count", descending=True)
)

animals_vertebrates = animals.filter(pl.col("Category") != "Invertebrate")

values = {
    "Bird":"#8EA163", 
    "Fish":"#1A8FA5", 
    "Mammal":"#EFCF72", 
    "Reptile":"#EF8C64", 
    "Amphibian":"#9DC9B7"
}

(
    ggplot(animals_vertebrates, aes(x = "count", y = as_discrete("ParkName", order_by="count", order = 1), fill = "Category")) +
           geom_bar(stat = "identity") +
           scale_fill_manual(values = values) +
           labs( # type: ignore
               title = "National Parks Ranked by Animal Biodiversity \n (excluding invertebrates) \n",
               x = "Number of Species",
               y = "Park Name"
           )
)
# Out:
# C:\Users\austi\AppData\Local\Temp\ipykernel_7324\3096078348.py:20: DeprecationWarning:
#
# `GroupBy.count` is deprecated. It has been renamed to `len`.
#    <div id="eGVCRE"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "ParkName":["Grand Canyon","Hot Springs","Acadia","Indiana Dunes","Yellowstone","Olympic","Joshua Tree","Zion","Rocky Mountain","Glacier","Yosemite","Great Smoky Mountains","Grand Teton","Cuyahoga Valley","Bryce Canyon","Great Smoky Mountains","Grand Canyon","Great Smoky Mountains","Olympic","Hot Springs","Yosemite","Cuyahoga Valley","Zion","Olympic","Yellowstone","Grand Canyon","Bryce Canyon","Indiana Dunes","Rocky Mountain","Grand Teton","Glacier","Joshua Tree","Indiana Dunes","Great Smoky Mountains","Acadia","Hot Springs","Hot Springs","Joshua Tree","Great Smoky Mountains","Cuyahoga Valley","Acadia","Indiana Dunes","Zion","Grand Canyon","Glacier","Hot Springs","Indiana Dunes","Cuyahoga Valley","Cuyahoga Valley","Grand Teton","Yosemite","Yellowstone","Olympic","Acadia","Zion","Grand Canyon","Yosemite","Bryce Canyon","Rocky Mountain","Acadia","Yosemite","Yellowstone","Yellowstone","Zion","Olympic","Glacier","Grand Teton","Joshua Tree","Rocky Mountain","Grand Teton","Bryce Canyon","Glacier","Rocky Mountain","Bryce Canyon","Joshua Tree"],
# "Category":["Bird","Bird","Bird","Bird","Bird","Bird","Bird","Bird","Bird","Bird","Bird","Bird","Bird","Bird","Bird","Fish","Mammal","Mammal","Fish","Fish","Mammal","Fish","Mammal","Mammal","Mammal","Reptile","Mammal","Fish","Mammal","Mammal","Mammal","Mammal","Mammal","Amphibian","Mammal","Reptile","Mammal","Reptile","Reptile","Mammal","Fish","Reptile","Reptile","Fish","Fish","Amphibian","Amphibian","Reptile","Amphibian","Fish","Reptile","Fish","Amphibian","Amphibian","Fish","Amphibian","Amphibian","Reptile","Fish","Reptile","Fish","Reptile","Amphibian","Amphibian","Reptile","Amphibian","Amphibian","Amphibian","Amphibian","Reptile","Amphibian","Reptile","Reptile","Fish","Fish"],
# "count":[456.0,387.0,364.0,353.0,330.0,310.0,301.0,301.0,278.0,277.0,270.0,267.0,266.0,246.0,218.0,110.0,107.0,101.0,97.0,90.0,87.0,85.0,80.0,79.0,78.0,76.0,76.0,76.0,75.0,74.0,69.0,67.0,60.0,58.0,55.0,52.0,52.0,52.0,47.0,47.0,38.0,30.0,30.0,29.0,27.0,27.0,24.0,24.0,24.0,23.0,22.0,19.0,16.0,15.0,15.0,15.0,14.0,13.0,12.0,11.0,10.0,9.0,9.0,7.0,6.0,6.0,6.0,5.0,5.0,5.0,4.0,4.0,3.0,1.0,1.0]
# },
# "mapping":{
# "x":"count",
# "y":"ParkName",
# "fill":"Category"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"ParkName"
# },{
# "type":"str",
# "column":"Category"
# },{
# "type":"int",
# "column":"count"
# }],
# "mapping_annotations":[{
# "parameters":{
# "label":"ParkName",
# "order_by":"count",
# "order":1.0
# },
# "aes":"y",
# "annotation":"as_discrete"
# }]
# },
# "ggtitle":{
# "text":"National Parks Ranked by Animal Biodiversity \n (excluding invertebrates) \n"
# },
# "guides":{
# "x":{
# "title":"Number of Species"
# },
# "y":{
# "title":"Park Name"
# }
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Bird","Fish","Mammal","Reptile","Amphibian"],
# "values":["#8EA163","#1A8FA5","#EFCF72","#EF8C64","#9DC9B7"]
# }],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "orientation":"y",
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("eGVCRE");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# (
#     ggplot(animals, aes(x = "count", y = as_discrete("ParkName", order_by="count", order = 1), fill = "Category")) +
#            geom_bar(stat = "identity") +
#            scale_fill_manual(values=["#8EA163", "#1A8FA5", "#EFCF72", "#EF8C64", "#9DC9B7"]) +
#            labs(
#                title = "National Parks Ranked by Animal Biodiversity \n (including invertebrates) \n",
#                x = "Number of Species",
#                y = "Park Name"
#            )
# )

# %%
plants = (
    species_data
    .filter(
        pl.col("CategoryName").is_in(["Vascular Plant", "Non-vascular Plant"])
    )
    .group_by(["ParkName", "CategoryName"])
    .count()
    .sort("count", descending=True)
)

(
    ggplot(plants, aes(x = "count", y = as_discrete("ParkName", order_by="count", order = 1), fill = "CategoryName")) + # type: ignore
           geom_bar(stat = "identity") + # type: ignore
           scale_fill_manual(values=["#8EA163", "#1A8FA5"]) +
           labs( # type: ignore
               title = "National Parks Ranked by Plant Biodiversity \n",
               x = "Number of Species",
               y = "Park Name"
           )
)
# Out:
# C:\Users\austi\AppData\Local\Temp\ipykernel_7324\2556515673.py:7: DeprecationWarning:
#
# `GroupBy.count` is deprecated. It has been renamed to `len`.
#    <div id="Tc5zW5"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "ParkName":["Great Smoky Mountains","Grand Canyon","Yosemite","Grand Teton","Indiana Dunes","Yellowstone","Zion","Olympic","Joshua Tree","Glacier","Hot Springs","Cuyahoga Valley","Acadia","Rocky Mountain","Great Smoky Mountains","Bryce Canyon","Rocky Mountain","Glacier","Hot Springs","Yellowstone","Joshua Tree"],
# "CategoryName":["Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Non-vascular Plant","Vascular Plant","Non-vascular Plant","Non-vascular Plant","Non-vascular Plant","Non-vascular Plant","Non-vascular Plant"],
# "count":[2163.0,1753.0,1683.0,1645.0,1622.0,1444.0,1366.0,1352.0,1314.0,1269.0,1252.0,1239.0,1226.0,1119.0,1039.0,975.0,416.0,404.0,18.0,15.0,6.0]
# },
# "mapping":{
# "x":"count",
# "y":"ParkName",
# "fill":"CategoryName"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"ParkName"
# },{
# "type":"str",
# "column":"CategoryName"
# },{
# "type":"int",
# "column":"count"
# }],
# "mapping_annotations":[{
# "parameters":{
# "label":"ParkName",
# "order_by":"count",
# "order":1.0
# },
# "aes":"y",
# "annotation":"as_discrete"
# }]
# },
# "ggtitle":{
# "text":"National Parks Ranked by Plant Biodiversity \n"
# },
# "guides":{
# "x":{
# "title":"Number of Species"
# },
# "y":{
# "title":"Park Name"
# }
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "values":["#8EA163","#1A8FA5"]
# }],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "orientation":"y",
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("Tc5zW5");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
misc = (
    species_data
    .filter(
        pl.col("CategoryName").is_in(["Fungi", "Chromista", "Bacteria", "Protozoa"])
    )
    .group_by(["ParkName", "CategoryName"])
    .count()
    .sort("count", descending=True)
)

(
    ggplot(misc, aes(x = "count", y = as_discrete("ParkName", order_by="count", order = 1), fill = "CategoryName")) +
           geom_bar(stat = "identity") +
           scale_fill_manual(values=["#8EA163", "#1A8FA5", "#EFCF72", "#EF8C64"]) +
           labs( # type: ignore
               title = "National Parks Ranked by Other Biodiversity \n",
               x = "Number of Species",
               y = "Park Name"
           )
)
# Out:
# C:\Users\austi\AppData\Local\Temp\ipykernel_7324\2649027645.py:7: DeprecationWarning:
#
# `GroupBy.count` is deprecated. It has been renamed to `len`.
#    <div id="V8fMWZ"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "ParkName":["Great Smoky Mountains","Great Smoky Mountains","Rocky Mountain","Great Smoky Mountains","Glacier","Great Smoky Mountains","Yellowstone","Rocky Mountain","Indiana Dunes","Rocky Mountain","Joshua Tree","Yellowstone","Grand Teton","Hot Springs","Joshua Tree","Yellowstone","Hot Springs","Hot Springs","Rocky Mountain","Joshua Tree","Yellowstone","Glacier","Grand Teton"],
# "CategoryName":["Fungi","Chromista","Fungi","Bacteria","Fungi","Protozoa","Chromista","Chromista","Fungi","Bacteria","Fungi","Fungi","Fungi","Chromista","Bacteria","Protozoa","Protozoa","Bacteria","Protozoa","Chromista","Bacteria","Chromista","Chromista"],
# "count":[5243.0,654.0,306.0,294.0,276.0,257.0,204.0,150.0,69.0,45.0,38.0,37.0,28.0,24.0,23.0,18.0,12.0,10.0,9.0,5.0,4.0,2.0,1.0]
# },
# "mapping":{
# "x":"count",
# "y":"ParkName",
# "fill":"CategoryName"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"ParkName"
# },{
# "type":"str",
# "column":"CategoryName"
# },{
# "type":"int",
# "column":"count"
# }],
# "mapping_annotations":[{
# "parameters":{
# "label":"ParkName",
# "order_by":"count",
# "order":1.0
# },
# "aes":"y",
# "annotation":"as_discrete"
# }]
# },
# "ggtitle":{
# "text":"National Parks Ranked by Other Biodiversity \n"
# },
# "guides":{
# "x":{
# "title":"Number of Species"
# },
# "y":{
# "title":"Park Name"
# }
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "values":["#8EA163","#1A8FA5","#EFCF72","#EF8C64"]
# }],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "orientation":"y",
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("V8fMWZ");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
animal_list = ("Mammal", "Bird", "Fish", "Reptile", "Amphibian", "Insect")
selected_park = "Zion"
specific_park_data = species_data.filter(pl.col("ParkName") == selected_park)

animals_in_park = (species_data
                   .filter((pl.col("ParkName") == selected_park) & (pl.col("CategoryName").is_in(animal_list)))
                   .group_by("CategoryName").agg(pl.col("CategoryName").count().alias("Count"))
                   )
animals_in_park
# Out:
# shape: (5, 2)
# ┌──────────────┬───────┐
# │ CategoryName ┆ Count │
# │ ---          ┆ ---   │
# │ str          ┆ u32   │
# ╞══════════════╪═══════╡
# │ Fish         ┆ 15    │
# │ Amphibian    ┆ 7     │
# │ Bird         ┆ 301   │
# │ Reptile      ┆ 30    │
# │ Mammal       ┆ 80    │
# └──────────────┴───────┘

# %%
from lets_plot import *

values = {
    "Bird":"#8EA163", 
    "Fish":"#1A8FA5", 
    "Mammal":"#EFCF72", 
    "Reptile":"#EF8C64", 
    "Amphibian":"#9DC9B7"
}

(
    ggplot(animals_in_park) +
    geom_pie(aes(slice = "Count", fill = "CategoryName"), stat = "identity") +
    scale_fill_manual(values = values) +
    theme_void()
)
# Out:
#    <div id="gDPXjU"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "CategoryName":["Fish","Amphibian","Bird","Reptile","Mammal"],
# "Count":[15.0,7.0,301.0,30.0,80.0]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"CategoryName"
# },{
# "type":"int",
# "column":"Count"
# }]
# },
# "theme":{
# "name":"classic",
# "line":"blank",
# "axis":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Bird","Fish","Mammal","Reptile","Amphibian"],
# "values":["#8EA163","#1A8FA5","#EFCF72","#EF8C64","#9DC9B7"]
# }],
# "layers":[{
# "geom":"pie",
# "stat":"identity",
# "mapping":{
# "slice":"Count",
# "fill":"CategoryName"
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("gDPXjU");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
